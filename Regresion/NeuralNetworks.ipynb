# %% [markdown]
# ___
# <img style="float: right; margin: 0px 0px 15px 15px;" src="https://bernardmarr.com/img/What%20is%20an%20Artificial%20Neural%20Networks.jpg" width="350px" height="180px" />
#
#
# # <font color= #8A0829> Laboratorio de Modelado de Datos </font>
# #### <font color= #2E9AFE> `Martes y Viernes (Videoconferencia) de 13:00 - 15:00 hrs`</font>
# - <Strong> Sara Eugenia Rodríguez </Strong>
# - <Strong> Año </Strong>: 2023
# - <Strong> Email: </Strong>  <font color="blue"> `cd682324@iteso.mx` </font>
# ___
#
# <p style="text-align:right;"> Imagen recuperada de: https://bernardmarr.com/img/What%20is%20an%20Artificial%20Neural%20Networks.jpg</p>
#
# ### <font color= #2E9AFE> Tema: Redes Neuronales</font>

# %% [markdown]
# **Aplicaciones de la vida real**
#
# - Control del vuelo de aviones
# - Control automotriz
# - Área médica
# - Optimizar el rendimiento del Wi-fi

# %%
from IPython.display import Image
Image(filename='compare_NN.JPG', width=600, height=400)

# %% [markdown]
# Dentro de la caja negra...
#
# **¿Qué es una neurona?**
#
# Es un nombre elegante que le pusieron para referirse a una función en los años de 1940-1950. Se creeía que los nodos eran como neuronas del cerebro.
#
# **¿Qué es una función?**
#
# Es un nombre elegante que pusieron para referirse a algo que toma cosas de entrada, aplica alguna lógica y saca un resultado.
#
# **¿Qué es una red neuronal?**
#
# Es la interconexión de múltiples neuronas (funciones) para resolver un problema complejo que una sola neurona no podría. Dentro de los componentes existen *nodos* y *conexiones*
#
# **Pasos que hace la red neuronal:**
#
# 1. Combinación de las variables de entrada (X). Cada señal recibida tiene una constante w (peso/weight) que permite manipular la importancia de cada variable de entrada.
# 2. Neurona de respuesta. Considerando todas las variables de entrada, la neurona genera una señal de respuesta a través de una función.
#
# **Tipos de capas en la red neuronal**
#
# - Capa de entrada: capa que toma los datos de entrada
# - Capas ocultas: toman las entradas de otra capa y pasan a salida hacia otra capa (son intermediarias entre la entrada y la salida)
# - Capas de salida: capa que hace la predicción
#
# <img style="float: center; margin: 0px 0px 0px 0px;" src="https://www.smartsheet.com/sites/default/files/IC-simplified-artificial-neural-networks-corrected.svg" width="350px" height="180px" />

# %%
from IPython.display import Image
Image(filename='neuron_weights.JPG', width=300, height=200)

# %% [markdown]
# **Modelo matemático de la neurona**
#
# $$\nu = w_{0}+w_{1}x_{1}+w_{2}x_{2}+w_{3}x_{3}+w_{4}x_{4}+w_{5}x_{5}$$
# $$y = \varphi(\nu)$$

# %%
from IPython.display import Image
Image(filename='capa_oculta.JPG', width=300, height=200)

# %% [markdown]
# **Modelo matemático red neuronal**
#
# $$\nu^{1} = w_{0}^{1}+w^{1}$$
# $$y^{1} = \varphi(\nu^{1})$$
# $$\nu^{2} = w_{0}^{2}+w^{2}y_{1}$$
# $$y^{2} = \varphi(\nu^{2})$$

# %%
from IPython.display import Image
Image(filename='capa_oculta2.JPG', width=300, height=200)

# %% [markdown]
# **Modelo matemático usando dos capas oculta**
#
# <font color= #66CC00>$$\nu^{1} = w_{0}^{1}+w^{1}$$</font>
# <font color= #66CC00>$$y^{1} = \varphi(\nu^{1})$$</font>
# <font color= #009900>$$\nu^{2} = w_{0}^{2}+w^{2}y_{1}$$</font>
# <font color= #009900>$$y^{2} = \varphi(\nu^{2})$$</font>
# <font color= #3399FF>$$\nu^{3} = w_{0}^{3}+w^{3}y_{2}$$</font>
# <font color= #3399FF>$$y^{3} = \varphi(\nu^{3})$$</font>
#
#
# **Funciones de activación**
#
# El comportamiento de las neuronas de las redes neuronales es basado en la función en la que la neurona se especializó. Una neurona puede cambiar su respuesta dependiendo de la función de activación $\varphi(*)$ que sea seleccionada
#
# Funciones comunes:
# 1. Lineal: $\varphi(\nu)=\nu$
# 2. Sigmoidal: $\varphi(\nu)=\frac{e^{\nu}}{1+e^{\nu}}$
# 3. Tanh: $\varphi(\nu)=\frac{e^{\nu}-e^{-\nu}}{e^{\nu}+e^{-\nu}}=tanh(\nu)$
# 4. Softplus: $\varphi(\nu)=log(1+e^{\nu})$
# 5. RELU: $\varphi(\nu)=max(0,\nu)$
#
# Las funciones de activación suelen ser diferenciables, lo que significa que la derivada de primer orden se puede calcular para un valor de entrada dado. Esto es necesario dado que las redes neuronales generalmente se entrenan utilizando el algoritmo de backpropagation que requiere la derivada del error de predicción para actualizar los pesos del modelo.
#
# **¿Cómo elegir la función de activación para las capas ocultas?**
#
# - Lineal: se recomienda para cuando el problema es sencillo
# - Sigmoidal: típicamente para problemas de clasificación. Sufre del problema de "Gradiente que se desvanece", los gradientes de la salida de la red con respecto a los parámetros se vuelven tan pequeños que la red neuronal da pasos más pequeños hacia los mínimos de la función de costo y finalmente deja de aprender.
# - Tanh: muy similar a la sigmoidal
# - RELU: es la más utilizada para capas ocultas. Es simple de implementar y no es tan susceptible a gradientes que se desvanecen
# - Softmax: no se recomienda mucho usarla ya que el cálculo de gradientes no es tan eficiente
#
# **¿Cómo son las redes neuronales para regresión?**
#
# $$\nu^{1} = w_{0}^{1}+w^{1}$$
# $$y^{1} = \varphi(\nu^{1})$$
# $$\nu^{2} = w_{0}^{2}+w^{2}y_{1}$$
# <font color= #2E9AFE>$$y^{2} = \varphi(\nu^{2})$$</font>
#
# La única diferencia es la última salida. La función de la salida tiene que ser **lineal**
#
# **Backpropagation**
#
# Es el método que usa para ajustar el modelo. Minimiza el error medio cuadrático (MSE), utilizando el gradiente descendente para calcular los parámetros con el orden del último hacia el primero.
#
# **¿Cómo elegir cuántas capas ocultas?**
#
# Se recomienda usar la regla de:
# (# capas ocultas = #entradas + # salidas)
#
# **¿Cómo elegir cuántas neuronas en las capas ocultas?**
#
# Depende....
#
# De forma ideal, el número de neuronas ocultas debe ser mayor al número de entradas (#Neuronas ocultas > # variables de entrada).
#
# Peroooo esta regla tiene varias formas de verse afectada:
#
# 1. Número de datos
# 2. Poder computacional
#
# Si se tienen pocos datos, al aumentar el número de neuronas ocultas, la cantidad de pesos se empieza a ser comparable con las muestras que se tienen, entonces conviene aumentar la cantidad de neuronas ocultas.
#
# Si se tienen muchos datos, esta regla de (#Neuronas ocultas > # variables de entrada) no es fácil por cuestiones computacionales, por lo tanto usamos las siguientes reglas:
#
# - El número de neuronas ocultas debe estar entre el tamaño de la capa de entrada y el tamaño de la capa de salida.
# - El número de neuronas ocultas debe ser 2/3 del tamaño de la capa de entrada, más el tamaño de la capa de salida.
# - El número de neuronas ocultas es la media de las neuronas en las capas de entrada y salida.
#
# **Recomendaciones**
#
# - Se recomienda hacer un pre-procesamiento de los datos - Escalamiento
# - Comúnmente todas las capas ocultas usan la misma función de activación
# - La función de salida generalmente usa diferente función de activación que el de las capas ocultas.
# - En la experiencia, conviene más aumentar el número de neuronas ocultas en lugar de aumentar el número de capas ocultas.
# - Se recomienda no usar muchas capas ocultas

# %%
#pip install scikeras
#pip install keras
#pip install tensorflow

#si por algo no funcionan los comandos anteriores... probar utilizando lo siguiente:
#conda install -c conda-forge keras
#conda install -c conda-forge/label/broken keras
#conda install -c conda-forge/label/cf201901 keras
#conda install -c conda-forge tensorflow=1.14


import keras
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation
from keras.optimizers import SGD, Adam
#from tensorflow.keras.optimizers import SGD
import matplotlib.pyplot as plt
import numpy as np
from sklearn.metrics import r2_score
# Out:
# C:\Users\Juan Pablo Colome\anaconda3\lib\site-packages\scipy\__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.24.3
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %% [markdown]
# #### Ejemplo de una sola variable (X)

# %%
#Generamos datos
#Generar la X
m = 1000;
X = np.linspace(-1,1,num=m)
X = np.reshape(X,(m,1))

#Generar la Y

#Y = X**2 #Función cuadrática
Y = 2*X**3+2*X**2 
#Y = 4*X*np.sin(10*X)+X*np.exp(X)*np.cos(20*X) 

[m,ne] = np.shape(X)

from sklearn import preprocessing
X = preprocessing.scale(X)
Y = preprocessing.scale(Y)

#graficando los datos
fig = plt.figure()
plt.plot(X,Y, linewidth=3)
plt.grid()

# %%
#Dividimos los datos en test y train
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, Y,
                                                    test_size=0.2, random_state=42)

# %%
# Diseño del modelo

#Inicializo objeto
model = Sequential()

#Agregar capas

#Agregamos la primera capa de entrada
#capa densa significa que todas las neuronas anteriores van con todas las que siguen
#Elegimos 5 neuronas en esa capa
#input_dim = 1 porque tenemos solo una X. Aquí nos preguntamos: ¿cuántas entradas voy a tener?
model.add(Dense(5, activation='relu', input_dim=1,name='capa_de_entrada'))


#si quisiéramos añadir capas ocultas
#model.add(Dense(10, activation='tanh', name='capa_oculta'))

#Agregamos la capa de salida
#la capa de salida tiene que ser lineal
model.add(Dense(1, activation='linear',name='capa_de_salida'))#LINEAL SIEMPRE A LA SALIDA


#HASTA AQUÍ HEMOS CREADO LA ESTRUCTURA
#...
#gradiente descendente
#épocas = cuántas veces se repite el gradiente descendente para encontrar el mínimo del MSE
#si la funcion de costo J tiene muchos picos, se recomienda disminuir el decaimineto o aumentar la tasa de aprendizaje
#Momentum: Utiliza la ley física del movimiento para atravesar óptimos locales (pequeñas colinas). 
#agrega un impulso que hará que la convergencia sea más rápida
#aqui construimis el gradeinte descendente.
#Hiperparámetros
learning_rate=0.1 #tasa de aprendizaje(tamaño del paso)
epochs = 200#epocas
momentum = 0.8#momentum:Ayuda a que no de tantos brincos mi algoritmo y encuentre mas rapido el optimo.(penaliza un poco la tasa de aprendizaje)
decay_rate = learning_rate/epochs
#Inicializamos el objeto
sgd = SGD(learning_rate=learning_rate, weight_decay=decay_rate, momentum=momentum)

#Funcion de costo
model.compile(loss='mean_squared_error',
              optimizer=sgd, 
             metrics = ['mse'])

# %%
#Ajustamos el modelo
history = model.fit(X_train, y_train, 
                   epochs=epochs, 
                   batch_size=100, 
                   validation_data=(X_test,y_test))
# Out:
# Epoch 1/200
# 8/8 [==============================] - 2s 36ms/step - loss: 0.6152 - mse: 0.6152 - val_loss: 0.2549 - val_mse: 0.2549
# Epoch 2/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.1638 - mse: 0.1638 - val_loss: 0.0796 - val_mse: 0.0796
# Epoch 3/200
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0540 - mse: 0.0540 - val_loss: 0.0332 - val_mse: 0.0332
# Epoch 4/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0261 - mse: 0.0261 - val_loss: 0.0242 - val_mse: 0.0242
# Epoch 5/200
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0190 - mse: 0.0190 - val_loss: 0.0178 - val_mse: 0.0178
# Epoch 6/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0163 - mse: 0.0163 - val_loss: 0.0162 - val_mse: 0.0162
# Epoch 7/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0157 - mse: 0.0157 - val_loss: 0.0160 - val_mse: 0.0160
# Epoch 8/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0144 - mse: 0.0144 - val_loss: 0.0141 - val_mse: 0.0141
# Epoch 9/200
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0142 - mse: 0.0142 - val_loss: 0.0191 - val_mse: 0.0191
# Epoch 10/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0156 - mse: 0.0156 - val_loss: 0.0132 - val_mse: 0.0132
# Epoch 11/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0139 - mse: 0.0139 - val_loss: 0.0130 - val_mse: 0.0130
# Epoch 12/200
# 8/8 [==============================] - 0s 7ms/step - loss: 0.0132 - mse: 0.0132 - val_loss: 0.0131 - val_mse: 0.0131
# Epoch 13/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0132 - mse: 0.0132 - val_loss: 0.0126 - val_mse: 0.0126
# Epoch 14/200
# 8/8 [==============================] - 0s 7ms/step - loss: 0.0135 - mse: 0.0135 - val_loss: 0.0129 - val_mse: 0.0129
# Epoch 15/200
# 8/8 [==============================] - 0s 7ms/step - loss: 0.0128 - mse: 0.0128 - val_loss: 0.0123 - val_mse: 0.0123
# Epoch 16/200
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0126 - mse: 0.0126 - val_loss: 0.0123 - val_mse: 0.0123
# Epoch 17/200
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0127 - mse: 0.0127 - val_loss: 0.0121 - val_mse: 0.0121
# Epoch 18/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0125 - mse: 0.0125 - val_loss: 0.0121 - val_mse: 0.0121
# Epoch 19/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0123 - mse: 0.0123 - val_loss: 0.0126 - val_mse: 0.0126
# Epoch 20/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0123 - mse: 0.0123 - val_loss: 0.0118 - val_mse: 0.0118
# Epoch 21/200
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0122 - mse: 0.0122 - val_loss: 0.0121 - val_mse: 0.0121
# Epoch 22/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0124 - mse: 0.0124 - val_loss: 0.0115 - val_mse: 0.0115
# Epoch 23/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0120 - mse: 0.0120 - val_loss: 0.0114 - val_mse: 0.0114
# Epoch 24/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0118 - mse: 0.0118 - val_loss: 0.0113 - val_mse: 0.0113
# Epoch 25/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0116 - mse: 0.0116 - val_loss: 0.0112 - val_mse: 0.0112
# Epoch 26/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0116 - mse: 0.0116 - val_loss: 0.0110 - val_mse: 0.0110
# Epoch 27/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0115 - mse: 0.0115 - val_loss: 0.0112 - val_mse: 0.0112
# Epoch 28/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0115 - mse: 0.0115 - val_loss: 0.0108 - val_mse: 0.0108
# Epoch 29/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0115 - mse: 0.0115 - val_loss: 0.0113 - val_mse: 0.0113
# Epoch 30/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0112 - mse: 0.0112 - val_loss: 0.0106 - val_mse: 0.0106
# Epoch 31/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0112 - mse: 0.0112 - val_loss: 0.0106 - val_mse: 0.0106
# Epoch 32/200
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0111 - mse: 0.0111 - val_loss: 0.0106 - val_mse: 0.0106
# Epoch 33/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0109 - mse: 0.0109 - val_loss: 0.0104 - val_mse: 0.0104
# Epoch 34/200
# 8/8 [==============================] - 0s 7ms/step - loss: 0.0108 - mse: 0.0108 - val_loss: 0.0104 - val_mse: 0.0104
# Epoch 35/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0108 - mse: 0.0108 - val_loss: 0.0109 - val_mse: 0.0109
# Epoch 36/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0112 - mse: 0.0112 - val_loss: 0.0101 - val_mse: 0.0101
# Epoch 37/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0111 - mse: 0.0111 - val_loss: 0.0099 - val_mse: 0.0099
# Epoch 38/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0111 - mse: 0.0111 - val_loss: 0.0111 - val_mse: 0.0111
# Epoch 39/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0106 - mse: 0.0106 - val_loss: 0.0100 - val_mse: 0.0100
# Epoch 40/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0103 - mse: 0.0103 - val_loss: 0.0098 - val_mse: 0.0098
# Epoch 41/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0103 - mse: 0.0103 - val_loss: 0.0098 - val_mse: 0.0098
# Epoch 42/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0104 - mse: 0.0104 - val_loss: 0.0098 - val_mse: 0.0098
# Epoch 43/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0101 - mse: 0.0101 - val_loss: 0.0095 - val_mse: 0.0095
# Epoch 44/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0102 - mse: 0.0102 - val_loss: 0.0094 - val_mse: 0.0094
# Epoch 45/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0100 - mse: 0.0100 - val_loss: 0.0096 - val_mse: 0.0096
# Epoch 46/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0100 - mse: 0.0100 - val_loss: 0.0093 - val_mse: 0.0093
# Epoch 47/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0100 - mse: 0.0100 - val_loss: 0.0095 - val_mse: 0.0095
# Epoch 48/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0105 - mse: 0.0105 - val_loss: 0.0092 - val_mse: 0.0092
# Epoch 49/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0099 - mse: 0.0099 - val_loss: 0.0090 - val_mse: 0.0090
# Epoch 50/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0097 - mse: 0.0097 - val_loss: 0.0092 - val_mse: 0.0092
# Epoch 51/200
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0100 - mse: 0.0100 - val_loss: 0.0092 - val_mse: 0.0092
# Epoch 52/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0097 - mse: 0.0097 - val_loss: 0.0089 - val_mse: 0.0089
# Epoch 53/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0095 - mse: 0.0095 - val_loss: 0.0089 - val_mse: 0.0089
# Epoch 54/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0094 - mse: 0.0094 - val_loss: 0.0087 - val_mse: 0.0087
# Epoch 55/200
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0097 - mse: 0.0097 - val_loss: 0.0090 - val_mse: 0.0090
# Epoch 56/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0096 - mse: 0.0096 - val_loss: 0.0086 - val_mse: 0.0086
# Epoch 57/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0094 - mse: 0.0094 - val_loss: 0.0091 - val_mse: 0.0091
# Epoch 58/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0094 - mse: 0.0094 - val_loss: 0.0089 - val_mse: 0.0089
# Epoch 59/200
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0093 - mse: 0.0093 - val_loss: 0.0086 - val_mse: 0.0086
# Epoch 60/200
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0093 - mse: 0.0093 - val_loss: 0.0085 - val_mse: 0.0085
# Epoch 61/200
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0093 - mse: 0.0093 - val_loss: 0.0085 - val_mse: 0.0085
# Epoch 62/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0093 - mse: 0.0093 - val_loss: 0.0084 - val_mse: 0.0084
# Epoch 63/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0093 - mse: 0.0093 - val_loss: 0.0083 - val_mse: 0.0083
# Epoch 64/200
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0092 - mse: 0.0092 - val_loss: 0.0084 - val_mse: 0.0084
# Epoch 65/200
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0092 - mse: 0.0092 - val_loss: 0.0085 - val_mse: 0.0085
# Epoch 66/200
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0092 - mse: 0.0092 - val_loss: 0.0084 - val_mse: 0.0084
# Epoch 67/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0092 - mse: 0.0092 - val_loss: 0.0083 - val_mse: 0.0083
# Epoch 68/200
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0091 - mse: 0.0091 - val_loss: 0.0082 - val_mse: 0.0082
# Epoch 69/200
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0090 - mse: 0.0090 - val_loss: 0.0083 - val_mse: 0.0083
# Epoch 70/200
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0090 - mse: 0.0090 - val_loss: 0.0080 - val_mse: 0.0080
# Epoch 71/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0090 - mse: 0.0090 - val_loss: 0.0081 - val_mse: 0.0081
# Epoch 72/200
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0090 - mse: 0.0090 - val_loss: 0.0081 - val_mse: 0.0081
# Epoch 73/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0089 - mse: 0.0089 - val_loss: 0.0080 - val_mse: 0.0080
# Epoch 74/200
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0089 - mse: 0.0089 - val_loss: 0.0081 - val_mse: 0.0081
# Epoch 75/200
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0090 - mse: 0.0090 - val_loss: 0.0081 - val_mse: 0.0081
# Epoch 76/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0089 - mse: 0.0089 - val_loss: 0.0082 - val_mse: 0.0082
# Epoch 77/200
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0089 - mse: 0.0089 - val_loss: 0.0080 - val_mse: 0.0080
# Epoch 78/200
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0089 - mse: 0.0089 - val_loss: 0.0079 - val_mse: 0.0079
# Epoch 79/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0089 - mse: 0.0089 - val_loss: 0.0079 - val_mse: 0.0079
# Epoch 80/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0089 - mse: 0.0089 - val_loss: 0.0084 - val_mse: 0.0084
# Epoch 81/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0088 - mse: 0.0088 - val_loss: 0.0078 - val_mse: 0.0078
# Epoch 82/200
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0089 - mse: 0.0089 - val_loss: 0.0080 - val_mse: 0.0080
# Epoch 83/200
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0088 - mse: 0.0088 - val_loss: 0.0078 - val_mse: 0.0078
# Epoch 84/200
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0088 - mse: 0.0088 - val_loss: 0.0079 - val_mse: 0.0079
# Epoch 85/200
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0088 - mse: 0.0088 - val_loss: 0.0082 - val_mse: 0.0082
# Epoch 86/200
# 8/8 [==============================] - 0s 8ms/step - loss: 0.0089 - mse: 0.0089 - val_loss: 0.0080 - val_mse: 0.0080
# Epoch 87/200
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0088 - mse: 0.0088 - val_loss: 0.0079 - val_mse: 0.0079
# Epoch 88/200
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0088 - mse: 0.0088 - val_loss: 0.0078 - val_mse: 0.0078
# Epoch 89/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0088 - mse: 0.0088 - val_loss: 0.0079 - val_mse: 0.0079
# Epoch 90/200
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0088 - mse: 0.0088 - val_loss: 0.0079 - val_mse: 0.0079
# Epoch 91/200
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0087 - mse: 0.0087 - val_loss: 0.0077 - val_mse: 0.0077
# Epoch 92/200
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0087 - mse: 0.0087 - val_loss: 0.0077 - val_mse: 0.0077
# Epoch 93/200
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0087 - mse: 0.0087 - val_loss: 0.0077 - val_mse: 0.0077
# Epoch 94/200
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0088 - mse: 0.0088 - val_loss: 0.0078 - val_mse: 0.0078
# Epoch 95/200
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0087 - mse: 0.0087 - val_loss: 0.0077 - val_mse: 0.0077
# Epoch 96/200
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0087 - mse: 0.0087 - val_loss: 0.0078 - val_mse: 0.0078
# Epoch 97/200
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0087 - mse: 0.0087 - val_loss: 0.0078 - val_mse: 0.0078
# Epoch 98/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0086 - mse: 0.0086 - val_loss: 0.0077 - val_mse: 0.0077
# Epoch 99/200
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0087 - mse: 0.0087 - val_loss: 0.0077 - val_mse: 0.0077
# Epoch 100/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0086 - mse: 0.0086 - val_loss: 0.0076 - val_mse: 0.0076
# Epoch 101/200
# 8/8 [==============================] - 0s 7ms/step - loss: 0.0087 - mse: 0.0087 - val_loss: 0.0078 - val_mse: 0.0078
# Epoch 102/200
# 8/8 [==============================] - 0s 7ms/step - loss: 0.0087 - mse: 0.0087 - val_loss: 0.0077 - val_mse: 0.0077
# Epoch 103/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0087 - mse: 0.0087 - val_loss: 0.0077 - val_mse: 0.0077
# Epoch 104/200
# 8/8 [==============================] - 0s 7ms/step - loss: 0.0086 - mse: 0.0086 - val_loss: 0.0077 - val_mse: 0.0077
# Epoch 105/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0087 - mse: 0.0087 - val_loss: 0.0077 - val_mse: 0.0077
# Epoch 106/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0087 - mse: 0.0087 - val_loss: 0.0078 - val_mse: 0.0078
# Epoch 107/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0088 - mse: 0.0088 - val_loss: 0.0079 - val_mse: 0.0079
# Epoch 108/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0088 - mse: 0.0088 - val_loss: 0.0077 - val_mse: 0.0077
# Epoch 109/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0088 - mse: 0.0088 - val_loss: 0.0080 - val_mse: 0.0080
# Epoch 110/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0090 - mse: 0.0090 - val_loss: 0.0079 - val_mse: 0.0079
# Epoch 111/200
# 8/8 [==============================] - 0s 7ms/step - loss: 0.0086 - mse: 0.0086 - val_loss: 0.0076 - val_mse: 0.0076
# Epoch 112/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0087 - mse: 0.0087 - val_loss: 0.0077 - val_mse: 0.0077
# Epoch 113/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0087 - mse: 0.0087 - val_loss: 0.0076 - val_mse: 0.0076
# Epoch 114/200
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0086 - mse: 0.0086 - val_loss: 0.0077 - val_mse: 0.0077
# Epoch 115/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0087 - mse: 0.0087 - val_loss: 0.0077 - val_mse: 0.0077
# Epoch 116/200
# 8/8 [==============================] - 0s 9ms/step - loss: 0.0088 - mse: 0.0088 - val_loss: 0.0077 - val_mse: 0.0077
# Epoch 117/200
# 8/8 [==============================] - 0s 12ms/step - loss: 0.0088 - mse: 0.0088 - val_loss: 0.0079 - val_mse: 0.0079
# Epoch 118/200
# 8/8 [==============================] - 0s 11ms/step - loss: 0.0087 - mse: 0.0087 - val_loss: 0.0084 - val_mse: 0.0084
# Epoch 119/200
# 8/8 [==============================] - 0s 11ms/step - loss: 0.0087 - mse: 0.0087 - val_loss: 0.0077 - val_mse: 0.0077
# Epoch 120/200
# 8/8 [==============================] - 0s 12ms/step - loss: 0.0086 - mse: 0.0086 - val_loss: 0.0076 - val_mse: 0.0076
# Epoch 121/200
# 8/8 [==============================] - 0s 12ms/step - loss: 0.0087 - mse: 0.0087 - val_loss: 0.0076 - val_mse: 0.0076
# Epoch 122/200
# 8/8 [==============================] - 0s 11ms/step - loss: 0.0087 - mse: 0.0087 - val_loss: 0.0077 - val_mse: 0.0077
# Epoch 123/200
# 8/8 [==============================] - 0s 11ms/step - loss: 0.0088 - mse: 0.0088 - val_loss: 0.0076 - val_mse: 0.0076
# Epoch 124/200
# 8/8 [==============================] - 0s 10ms/step - loss: 0.0088 - mse: 0.0088 - val_loss: 0.0078 - val_mse: 0.0078
# Epoch 125/200
# 8/8 [==============================] - 0s 11ms/step - loss: 0.0086 - mse: 0.0086 - val_loss: 0.0076 - val_mse: 0.0076
# Epoch 126/200
# 8/8 [==============================] - 0s 11ms/step - loss: 0.0086 - mse: 0.0086 - val_loss: 0.0075 - val_mse: 0.0075
# Epoch 127/200
# 8/8 [==============================] - 0s 11ms/step - loss: 0.0087 - mse: 0.0087 - val_loss: 0.0077 - val_mse: 0.0077
# Epoch 128/200
# 8/8 [==============================] - 0s 11ms/step - loss: 0.0087 - mse: 0.0087 - val_loss: 0.0076 - val_mse: 0.0076
# Epoch 129/200
# 8/8 [==============================] - 0s 11ms/step - loss: 0.0086 - mse: 0.0086 - val_loss: 0.0076 - val_mse: 0.0076
# Epoch 130/200
# 8/8 [==============================] - 0s 11ms/step - loss: 0.0086 - mse: 0.0086 - val_loss: 0.0077 - val_mse: 0.0077
# Epoch 131/200
# 8/8 [==============================] - 0s 11ms/step - loss: 0.0086 - mse: 0.0086 - val_loss: 0.0076 - val_mse: 0.0076
# Epoch 132/200
# 8/8 [==============================] - 0s 12ms/step - loss: 0.0087 - mse: 0.0087 - val_loss: 0.0076 - val_mse: 0.0076
# Epoch 133/200
# 8/8 [==============================] - 0s 11ms/step - loss: 0.0087 - mse: 0.0087 - val_loss: 0.0077 - val_mse: 0.0077
# Epoch 134/200
# 8/8 [==============================] - 0s 12ms/step - loss: 0.0087 - mse: 0.0087 - val_loss: 0.0077 - val_mse: 0.0077
# Epoch 135/200
# 8/8 [==============================] - 0s 11ms/step - loss: 0.0087 - mse: 0.0087 - val_loss: 0.0079 - val_mse: 0.0079
# Epoch 136/200
# 8/8 [==============================] - 0s 11ms/step - loss: 0.0087 - mse: 0.0087 - val_loss: 0.0076 - val_mse: 0.0076
# Epoch 137/200
# 8/8 [==============================] - 0s 11ms/step - loss: 0.0086 - mse: 0.0086 - val_loss: 0.0076 - val_mse: 0.0076
# Epoch 138/200
# 8/8 [==============================] - 0s 11ms/step - loss: 0.0086 - mse: 0.0086 - val_loss: 0.0078 - val_mse: 0.0078
# Epoch 139/200
# 8/8 [==============================] - 0s 12ms/step - loss: 0.0086 - mse: 0.0086 - val_loss: 0.0079 - val_mse: 0.0079
# Epoch 140/200
# 8/8 [==============================] - 0s 11ms/step - loss: 0.0086 - mse: 0.0086 - val_loss: 0.0076 - val_mse: 0.0076
# Epoch 141/200
# 8/8 [==============================] - 0s 11ms/step - loss: 0.0086 - mse: 0.0086 - val_loss: 0.0077 - val_mse: 0.0077
# Epoch 142/200
# 8/8 [==============================] - 0s 11ms/step - loss: 0.0087 - mse: 0.0087 - val_loss: 0.0075 - val_mse: 0.0075
# Epoch 143/200
# 8/8 [==============================] - 0s 12ms/step - loss: 0.0087 - mse: 0.0087 - val_loss: 0.0078 - val_mse: 0.0078
# Epoch 144/200
# 8/8 [==============================] - 0s 11ms/step - loss: 0.0086 - mse: 0.0086 - val_loss: 0.0079 - val_mse: 0.0079
# Epoch 145/200
# 8/8 [==============================] - 0s 11ms/step - loss: 0.0087 - mse: 0.0087 - val_loss: 0.0081 - val_mse: 0.0081
# Epoch 146/200
# 8/8 [==============================] - 0s 12ms/step - loss: 0.0087 - mse: 0.0087 - val_loss: 0.0076 - val_mse: 0.0076
# Epoch 147/200
# 8/8 [==============================] - 0s 10ms/step - loss: 0.0086 - mse: 0.0086 - val_loss: 0.0077 - val_mse: 0.0077
# Epoch 148/200
# 8/8 [==============================] - 0s 11ms/step - loss: 0.0086 - mse: 0.0086 - val_loss: 0.0076 - val_mse: 0.0076
# Epoch 149/200
# 8/8 [==============================] - 0s 10ms/step - loss: 0.0086 - mse: 0.0086 - val_loss: 0.0076 - val_mse: 0.0076
# Epoch 150/200
# 8/8 [==============================] - 0s 11ms/step - loss: 0.0086 - mse: 0.0086 - val_loss: 0.0076 - val_mse: 0.0076
# Epoch 151/200
# 8/8 [==============================] - 0s 10ms/step - loss: 0.0087 - mse: 0.0087 - val_loss: 0.0081 - val_mse: 0.0081
# Epoch 152/200
# 8/8 [==============================] - 0s 10ms/step - loss: 0.0087 - mse: 0.0087 - val_loss: 0.0076 - val_mse: 0.0076
# Epoch 153/200
# 8/8 [==============================] - 0s 11ms/step - loss: 0.0086 - mse: 0.0086 - val_loss: 0.0076 - val_mse: 0.0076
# Epoch 154/200
# 8/8 [==============================] - 0s 11ms/step - loss: 0.0086 - mse: 0.0086 - val_loss: 0.0076 - val_mse: 0.0076
# Epoch 155/200
# 8/8 [==============================] - 0s 11ms/step - loss: 0.0088 - mse: 0.0088 - val_loss: 0.0077 - val_mse: 0.0077
# Epoch 156/200
# 8/8 [==============================] - 0s 10ms/step - loss: 0.0088 - mse: 0.0088 - val_loss: 0.0079 - val_mse: 0.0079
# Epoch 157/200
# 8/8 [==============================] - 0s 10ms/step - loss: 0.0086 - mse: 0.0086 - val_loss: 0.0076 - val_mse: 0.0076
# Epoch 158/200
# 8/8 [==============================] - 0s 10ms/step - loss: 0.0086 - mse: 0.0086 - val_loss: 0.0084 - val_mse: 0.0084
# Epoch 159/200
# 8/8 [==============================] - 0s 10ms/step - loss: 0.0088 - mse: 0.0088 - val_loss: 0.0077 - val_mse: 0.0077
# Epoch 160/200
# 8/8 [==============================] - 0s 10ms/step - loss: 0.0086 - mse: 0.0086 - val_loss: 0.0076 - val_mse: 0.0076
# Epoch 161/200
# 8/8 [==============================] - 0s 10ms/step - loss: 0.0087 - mse: 0.0087 - val_loss: 0.0076 - val_mse: 0.0076
# Epoch 162/200
# 8/8 [==============================] - 0s 11ms/step - loss: 0.0087 - mse: 0.0087 - val_loss: 0.0075 - val_mse: 0.0075
# Epoch 163/200
# 8/8 [==============================] - 0s 10ms/step - loss: 0.0086 - mse: 0.0086 - val_loss: 0.0079 - val_mse: 0.0079
# Epoch 164/200
# 8/8 [==============================] - 0s 10ms/step - loss: 0.0086 - mse: 0.0086 - val_loss: 0.0078 - val_mse: 0.0078
# Epoch 165/200
# 8/8 [==============================] - 0s 10ms/step - loss: 0.0087 - mse: 0.0087 - val_loss: 0.0078 - val_mse: 0.0078
# Epoch 166/200
# 8/8 [==============================] - 0s 10ms/step - loss: 0.0086 - mse: 0.0086 - val_loss: 0.0076 - val_mse: 0.0076
# Epoch 167/200
# 8/8 [==============================] - 0s 11ms/step - loss: 0.0085 - mse: 0.0085 - val_loss: 0.0077 - val_mse: 0.0077
# Epoch 168/200
# 8/8 [==============================] - 0s 10ms/step - loss: 0.0087 - mse: 0.0087 - val_loss: 0.0076 - val_mse: 0.0076
# Epoch 169/200
# 8/8 [==============================] - 0s 10ms/step - loss: 0.0087 - mse: 0.0087 - val_loss: 0.0076 - val_mse: 0.0076
# Epoch 170/200
# 8/8 [==============================] - 0s 11ms/step - loss: 0.0087 - mse: 0.0087 - val_loss: 0.0077 - val_mse: 0.0077
# Epoch 171/200
# 8/8 [==============================] - 0s 10ms/step - loss: 0.0087 - mse: 0.0087 - val_loss: 0.0076 - val_mse: 0.0076
# Epoch 172/200
# 8/8 [==============================] - 0s 10ms/step - loss: 0.0086 - mse: 0.0086 - val_loss: 0.0076 - val_mse: 0.0076
# Epoch 173/200
# 8/8 [==============================] - 0s 10ms/step - loss: 0.0087 - mse: 0.0087 - val_loss: 0.0084 - val_mse: 0.0084
# Epoch 174/200
# 8/8 [==============================] - 0s 10ms/step - loss: 0.0089 - mse: 0.0089 - val_loss: 0.0081 - val_mse: 0.0081
# Epoch 175/200
# 8/8 [==============================] - 0s 10ms/step - loss: 0.0089 - mse: 0.0089 - val_loss: 0.0076 - val_mse: 0.0076
# Epoch 176/200
# 8/8 [==============================] - 0s 10ms/step - loss: 0.0086 - mse: 0.0086 - val_loss: 0.0076 - val_mse: 0.0076
# Epoch 177/200
# 8/8 [==============================] - 0s 11ms/step - loss: 0.0087 - mse: 0.0087 - val_loss: 0.0075 - val_mse: 0.0075
# Epoch 178/200
# 8/8 [==============================] - 0s 10ms/step - loss: 0.0087 - mse: 0.0087 - val_loss: 0.0079 - val_mse: 0.0079
# Epoch 179/200
# 8/8 [==============================] - 0s 14ms/step - loss: 0.0087 - mse: 0.0087 - val_loss: 0.0076 - val_mse: 0.0076
# Epoch 180/200
# 8/8 [==============================] - 0s 10ms/step - loss: 0.0086 - mse: 0.0086 - val_loss: 0.0077 - val_mse: 0.0077
# Epoch 181/200
# 8/8 [==============================] - 0s 10ms/step - loss: 0.0086 - mse: 0.0086 - val_loss: 0.0077 - val_mse: 0.0077
# Epoch 182/200
# 8/8 [==============================] - 0s 10ms/step - loss: 0.0086 - mse: 0.0086 - val_loss: 0.0075 - val_mse: 0.0075
# Epoch 183/200
# 8/8 [==============================] - 0s 10ms/step - loss: 0.0086 - mse: 0.0086 - val_loss: 0.0078 - val_mse: 0.0078
# Epoch 184/200
# 8/8 [==============================] - 0s 10ms/step - loss: 0.0088 - mse: 0.0088 - val_loss: 0.0076 - val_mse: 0.0076
# Epoch 185/200
# 8/8 [==============================] - 0s 11ms/step - loss: 0.0086 - mse: 0.0086 - val_loss: 0.0076 - val_mse: 0.0076
# Epoch 186/200
# 8/8 [==============================] - 0s 10ms/step - loss: 0.0086 - mse: 0.0086 - val_loss: 0.0077 - val_mse: 0.0077
# Epoch 187/200
# 8/8 [==============================] - 0s 12ms/step - loss: 0.0087 - mse: 0.0087 - val_loss: 0.0078 - val_mse: 0.0078
# Epoch 188/200
# 8/8 [==============================] - 0s 11ms/step - loss: 0.0087 - mse: 0.0087 - val_loss: 0.0076 - val_mse: 0.0076
# Epoch 189/200
# 8/8 [==============================] - 0s 10ms/step - loss: 0.0088 - mse: 0.0088 - val_loss: 0.0075 - val_mse: 0.0075
# Epoch 190/200
# 8/8 [==============================] - 0s 11ms/step - loss: 0.0086 - mse: 0.0086 - val_loss: 0.0077 - val_mse: 0.0077
# Epoch 191/200
# 8/8 [==============================] - 0s 12ms/step - loss: 0.0087 - mse: 0.0087 - val_loss: 0.0079 - val_mse: 0.0079
# Epoch 192/200
# 8/8 [==============================] - 0s 10ms/step - loss: 0.0088 - mse: 0.0088 - val_loss: 0.0078 - val_mse: 0.0078
# Epoch 193/200
# 8/8 [==============================] - 0s 11ms/step - loss: 0.0088 - mse: 0.0088 - val_loss: 0.0076 - val_mse: 0.0076
# Epoch 194/200
# 8/8 [==============================] - 0s 10ms/step - loss: 0.0086 - mse: 0.0086 - val_loss: 0.0076 - val_mse: 0.0076
# Epoch 195/200
# 8/8 [==============================] - 0s 10ms/step - loss: 0.0086 - mse: 0.0086 - val_loss: 0.0075 - val_mse: 0.0075
# Epoch 196/200
# 8/8 [==============================] - 0s 11ms/step - loss: 0.0086 - mse: 0.0086 - val_loss: 0.0078 - val_mse: 0.0078
# Epoch 197/200
# 8/8 [==============================] - 0s 10ms/step - loss: 0.0086 - mse: 0.0086 - val_loss: 0.0076 - val_mse: 0.0076
# Epoch 198/200
# 8/8 [==============================] - 0s 10ms/step - loss: 0.0087 - mse: 0.0087 - val_loss: 0.0076 - val_mse: 0.0076
# Epoch 199/200
# 8/8 [==============================] - 0s 10ms/step - loss: 0.0087 - mse: 0.0087 - val_loss: 0.0076 - val_mse: 0.0076
# Epoch 200/200
# 8/8 [==============================] - 0s 11ms/step - loss: 0.0086 - mse: 0.0086 - val_loss: 0.0078 - val_mse: 0.0078

# %%
#Graficar el MSE
fig, ax = plt.subplots(1, 1, figsize=(10,6))
ax.plot(np.sqrt(history.history['mse']), 'r', label='train')
ax.plot(np.sqrt(history.history['val_mse']), 'b' ,label='val')
ax.set_xlabel(r'Epoch', fontsize=20)
ax.set_ylabel(r'MSE', fontsize=20)
ax.legend()
ax.tick_params(labelsize=20)

# %%
#Evaluación del modelo

#Evaluación del modelo en los datos de prueba
score = model.evaluate(X_test,y_test)
print('Test mse:', score[1])
# Out:
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0078 - mse: 0.0078
# Test mse: 0.007752754259854555

# %%
#Predicción  y calcular R2

#Con datos del test
yhat = model.predict(X_test)
R2_score = r2_score(y_test,yhat)
xmin,xmax = min(y_test),max(y_test)
xline = np.linspace(xmin,xmax)
fig = plt.figure(figsize=(10,6))
plt.scatter(y_test,yhat,label='Estimation')
plt.plot(xline,xline,'k--',label='Perfect estimation')
plt.xlabel('Real output', fontsize=20)
plt.ylabel('Estimation output', fontsize=20)
plt.title('Test R^2=%0.4f'%R2_score, fontsize=20)
plt.legend()
plt.grid()
plt.show()
# Out:
# 7/7 [==============================] - 0s 2ms/step

# %%
print('R2:', R2_score)
# Out:
# R2: 0.99283088675695

# %% [markdown]
# #### Ejemplo Multivariable (Más de una variable de entrada X)

# %%
m = 100;
X = np.linspace(-1,1,num=m)
[x1,x2] = np.meshgrid(X,X)
X = np.c_[x1.ravel(),x2.ravel()]
Y = X[:,0]**2+X[:,1]**2 

[m,ne] = np.shape(X)
Y = np.reshape(Y,(m,1))

from sklearn import preprocessing
X = preprocessing.scale(X)
Y = preprocessing.scale(Y)

#from mpl_toolkits.mplot3d import Axes3D
fig = plt.figure(figsize=(20,10))
ax = fig.add_subplot(111, projection='3d')
ax.scatter(X[:,0], X[:,1], Y)

# %%
#Dividimos los datos en test y train
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, Y,
                                                    test_size=0.2, random_state=42)

# %%
# Diseño del modelo

#Inicializo objeto
model = Sequential()

#Agregar capas

#Agregamos la primera capa de entrada
model.add(Dense(5, activation='relu', input_dim=2,name='input_layer')) #tanh
#imput dim=2 porque son 2 x y son 2 datos de entrada
#Si quisiera añadir una capa oculta extra
#model.add(Dense(10, activation='tanh', name='hidden_layer'))
#Agregamos la capa de salida
model.add(Dense(1, activation='linear',name='output_layer'))

#hiperparámetros
epochs = 200
momentum = 0.8
decay_rate = learning_rate/epochs
sgd = SGD(learning_rate=learning_rate, weight_decay=decay_rate, momentum=momentum)
model.compile(loss='mean_squared_error',
              optimizer=sgd, 
             metrics = ['mse'])

# %%
#Ajustamos el modelo
history = model.fit(X_train, y_train, 
                   epochs=epochs, 
                   batch_size=100, 
                   validation_data=(X_test,y_test))
# Out:
# Epoch 1/200
# 80/80 [==============================] - 1s 3ms/step - loss: 0.2573 - mse: 0.2573 - val_loss: 0.0985 - val_mse: 0.0985
# Epoch 2/200
# 80/80 [==============================] - 0s 2ms/step - loss: 0.0869 - mse: 0.0869 - val_loss: 0.0678 - val_mse: 0.0678
# Epoch 3/200
# 80/80 [==============================] - 0s 2ms/step - loss: 0.0916 - mse: 0.0916 - val_loss: 0.0621 - val_mse: 0.0621
# Epoch 4/200
# 80/80 [==============================] - 0s 2ms/step - loss: 0.1017 - mse: 0.1017 - val_loss: 0.1586 - val_mse: 0.1586
# Epoch 5/200
# 80/80 [==============================] - 0s 2ms/step - loss: 0.0783 - mse: 0.0783 - val_loss: 0.1690 - val_mse: 0.1690
# Epoch 6/200
# 80/80 [==============================] - 0s 2ms/step - loss: 0.1003 - mse: 0.1003 - val_loss: 0.1832 - val_mse: 0.1832
# Epoch 7/200
# 80/80 [==============================] - 0s 2ms/step - loss: 0.1260 - mse: 0.1260 - val_loss: 0.0569 - val_mse: 0.0569
# Epoch 8/200
# 80/80 [==============================] - 0s 2ms/step - loss: 0.0951 - mse: 0.0951 - val_loss: 0.2228 - val_mse: 0.2228
# Epoch 9/200
# 80/80 [==============================] - 0s 2ms/step - loss: 0.0858 - mse: 0.0858 - val_loss: 0.0710 - val_mse: 0.0710
# Epoch 10/200
# 80/80 [==============================] - 0s 2ms/step - loss: 0.0668 - mse: 0.0668 - val_loss: 0.0728 - val_mse: 0.0728
# Epoch 11/200
# 80/80 [==============================] - 0s 2ms/step - loss: 0.0787 - mse: 0.0787 - val_loss: 0.0886 - val_mse: 0.0886
# Epoch 12/200
# 80/80 [==============================] - 0s 2ms/step - loss: 0.0940 - mse: 0.0940 - val_loss: 0.0801 - val_mse: 0.0801
# Epoch 13/200
# 80/80 [==============================] - 0s 2ms/step - loss: 0.0903 - mse: 0.0903 - val_loss: 0.1056 - val_mse: 0.1056
# Epoch 14/200
# 80/80 [==============================] - 0s 2ms/step - loss: 0.1014 - mse: 0.1014 - val_loss: 0.1503 - val_mse: 0.1503
# Epoch 15/200
# 80/80 [==============================] - 0s 2ms/step - loss: 0.1146 - mse: 0.1146 - val_loss: 0.0744 - val_mse: 0.0744
# Epoch 16/200
# 80/80 [==============================] - 0s 2ms/step - loss: 0.1018 - mse: 0.1018 - val_loss: 0.2843 - val_mse: 0.2843
# Epoch 17/200
# 80/80 [==============================] - 0s 2ms/step - loss: 0.1075 - mse: 0.1075 - val_loss: 0.0770 - val_mse: 0.0770
# Epoch 18/200
# 80/80 [==============================] - 0s 2ms/step - loss: 0.0844 - mse: 0.0844 - val_loss: 0.1771 - val_mse: 0.1771
# Epoch 19/200
# 80/80 [==============================] - 0s 2ms/step - loss: 0.0989 - mse: 0.0989 - val_loss: 0.0721 - val_mse: 0.0721
# Epoch 20/200
# 80/80 [==============================] - 0s 2ms/step - loss: 0.1260 - mse: 0.1260 - val_loss: 0.1222 - val_mse: 0.1222
# Epoch 21/200
# 80/80 [==============================] - 0s 2ms/step - loss: 0.1056 - mse: 0.1056 - val_loss: 0.1006 - val_mse: 0.1006
# Epoch 22/200
# 80/80 [==============================] - 0s 2ms/step - loss: 0.0861 - mse: 0.0861 - val_loss: 0.1078 - val_mse: 0.1078
# Epoch 23/200
# 80/80 [==============================] - 0s 2ms/step - loss: 0.0835 - mse: 0.0835 - val_loss: 0.0601 - val_mse: 0.0601
# Epoch 24/200
# 80/80 [==============================] - 0s 2ms/step - loss: 0.1026 - mse: 0.1026 - val_loss: 0.2559 - val_mse: 0.2559
# Epoch 25/200
# 80/80 [==============================] - 0s 2ms/step - loss: 0.0998 - mse: 0.0998 - val_loss: 0.0745 - val_mse: 0.0745
# Epoch 26/200
# 80/80 [==============================] - 0s 2ms/step - loss: 0.0892 - mse: 0.0892 - val_loss: 0.1410 - val_mse: 0.1410
# Epoch 27/200
# 80/80 [==============================] - 0s 2ms/step - loss: 0.0856 - mse: 0.0856 - val_loss: 0.0562 - val_mse: 0.0562
# Epoch 28/200
# 80/80 [==============================] - 0s 2ms/step - loss: 0.1884 - mse: 0.1884 - val_loss: 0.0579 - val_mse: 0.0579
# Epoch 29/200
# 80/80 [==============================] - 0s 2ms/step - loss: 0.0875 - mse: 0.0875 - val_loss: 0.0633 - val_mse: 0.0633
# Epoch 30/200
# 80/80 [==============================] - 0s 2ms/step - loss: 0.0751 - mse: 0.0751 - val_loss: 0.0839 - val_mse: 0.0839
# Epoch 31/200
# 80/80 [==============================] - 0s 2ms/step - loss: 0.0830 - mse: 0.0830 - val_loss: 0.0615 - val_mse: 0.0615
# Epoch 32/200
# 80/80 [==============================] - 0s 2ms/step - loss: 0.1132 - mse: 0.1132 - val_loss: 0.0929 - val_mse: 0.0929
# Epoch 33/200
# 80/80 [==============================] - 0s 2ms/step - loss: 0.1013 - mse: 0.1013 - val_loss: 0.2085 - val_mse: 0.2085
# Epoch 34/200
# 80/80 [==============================] - 0s 2ms/step - loss: 0.0929 - mse: 0.0929 - val_loss: 0.1097 - val_mse: 0.1097
# Epoch 35/200
# 80/80 [==============================] - 0s 2ms/step - loss: 0.0931 - mse: 0.0931 - val_loss: 0.0707 - val_mse: 0.0707
# Epoch 36/200
# 80/80 [==============================] - 0s 2ms/step - loss: 0.0747 - mse: 0.0747 - val_loss: 0.0532 - val_mse: 0.0532
# Epoch 37/200
# 80/80 [==============================] - 0s 2ms/step - loss: 0.1207 - mse: 0.1207 - val_loss: 0.0547 - val_mse: 0.0547
# Epoch 38/200
# 80/80 [==============================] - 0s 2ms/step - loss: 0.0800 - mse: 0.0800 - val_loss: 0.1145 - val_mse: 0.1145
# Epoch 39/200
# 80/80 [==============================] - 0s 2ms/step - loss: 0.0836 - mse: 0.0836 - val_loss: 0.0540 - val_mse: 0.0540
# Epoch 40/200
# 80/80 [==============================] - 0s 2ms/step - loss: 0.0869 - mse: 0.0869 - val_loss: 0.0587 - val_mse: 0.0587
# Epoch 41/200
# 80/80 [==============================] - 0s 2ms/step - loss: 0.0975 - mse: 0.0975 - val_loss: 0.0556 - val_mse: 0.0556
# Epoch 42/200
# 80/80 [==============================] - 0s 2ms/step - loss: 0.0917 - mse: 0.0917 - val_loss: 0.0778 - val_mse: 0.0778
# Epoch 43/200
# 80/80 [==============================] - 0s 2ms/step - loss: 0.0768 - mse: 0.0768 - val_loss: 0.1281 - val_mse: 0.1281
# Epoch 44/200
# 80/80 [==============================] - 0s 2ms/step - loss: 0.0849 - mse: 0.0849 - val_loss: 0.0864 - val_mse: 0.0864
# Epoch 45/200
# 80/80 [==============================] - 0s 2ms/step - loss: 0.0733 - mse: 0.0733 - val_loss: 0.1143 - val_mse: 0.1143
# Epoch 46/200
# 80/80 [==============================] - 0s 2ms/step - loss: 0.0842 - mse: 0.0842 - val_loss: 0.0992 - val_mse: 0.0992
# Epoch 47/200
# 80/80 [==============================] - 0s 2ms/step - loss: 0.0902 - mse: 0.0902 - val_loss: 0.0550 - val_mse: 0.0550
# Epoch 48/200
# 80/80 [==============================] - 0s 2ms/step - loss: 0.1247 - mse: 0.1247 - val_loss: 0.0558 - val_mse: 0.0558
# Epoch 49/200
# 80/80 [==============================] - 0s 2ms/step - loss: 0.0962 - mse: 0.0962 - val_loss: 0.0768 - val_mse: 0.0768
# Epoch 50/200
# 80/80 [==============================] - 0s 2ms/step - loss: 0.0755 - mse: 0.0755 - val_loss: 0.0517 - val_mse: 0.0517
# Epoch 51/200
# 80/80 [==============================] - 0s 2ms/step - loss: 0.0952 - mse: 0.0952 - val_loss: 0.1203 - val_mse: 0.1203
# Epoch 52/200
# 80/80 [==============================] - 0s 2ms/step - loss: 0.0771 - mse: 0.0771 - val_loss: 0.0621 - val_mse: 0.0621
# Epoch 53/200
# 80/80 [==============================] - 0s 2ms/step - loss: 0.0785 - mse: 0.0785 - val_loss: 0.1148 - val_mse: 0.1148
# Epoch 54/200
# 80/80 [==============================] - 0s 2ms/step - loss: 0.1008 - mse: 0.1008 - val_loss: 0.0687 - val_mse: 0.0687
# Epoch 55/200
# 80/80 [==============================] - 0s 2ms/step - loss: 0.0789 - mse: 0.0789 - val_loss: 0.0549 - val_mse: 0.0549
# Epoch 56/200
# 80/80 [==============================] - 0s 2ms/step - loss: 0.0769 - mse: 0.0769 - val_loss: 0.1119 - val_mse: 0.1119
# Epoch 57/200
# 80/80 [==============================] - 0s 2ms/step - loss: 0.0766 - mse: 0.0766 - val_loss: 0.0553 - val_mse: 0.0553
# Epoch 58/200
# 80/80 [==============================] - 0s 2ms/step - loss: 0.0997 - mse: 0.0997 - val_loss: 0.0606 - val_mse: 0.0606
# Epoch 59/200
# 80/80 [==============================] - 0s 2ms/step - loss: 0.0754 - mse: 0.0754 - val_loss: 0.1743 - val_mse: 0.1743
# Epoch 60/200
# 80/80 [==============================] - 0s 2ms/step - loss: 0.0964 - mse: 0.0964 - val_loss: 0.0577 - val_mse: 0.0577
# Epoch 61/200
# 80/80 [==============================] - 0s 2ms/step - loss: 0.0935 - mse: 0.0935 - val_loss: 0.0529 - val_mse: 0.0529
# Epoch 62/200
# 80/80 [==============================] - 0s 2ms/step - loss: 0.0750 - mse: 0.0750 - val_loss: 0.1087 - val_mse: 0.1087
# Epoch 63/200
# 80/80 [==============================] - 0s 2ms/step - loss: 0.0848 - mse: 0.0848 - val_loss: 0.0587 - val_mse: 0.0587
# Epoch 64/200
# 80/80 [==============================] - 0s 2ms/step - loss: 0.1104 - mse: 0.1104 - val_loss: 0.0638 - val_mse: 0.0638
# Epoch 65/200
# 80/80 [==============================] - 0s 2ms/step - loss: 0.0744 - mse: 0.0744 - val_loss: 0.0859 - val_mse: 0.0859
# Epoch 66/200
# 80/80 [==============================] - 0s 2ms/step - loss: 0.0926 - mse: 0.0926 - val_loss: 0.1099 - val_mse: 0.1099
# Epoch 67/200
# 80/80 [==============================] - 0s 2ms/step - loss: 0.0894 - mse: 0.0894 - val_loss: 0.0583 - val_mse: 0.0583
# Epoch 68/200
# 80/80 [==============================] - 0s 3ms/step - loss: 0.1253 - mse: 0.1253 - val_loss: 0.0835 - val_mse: 0.0835
# Epoch 69/200
# 80/80 [==============================] - 0s 2ms/step - loss: 0.0822 - mse: 0.0822 - val_loss: 0.0905 - val_mse: 0.0905
# Epoch 70/200
# 80/80 [==============================] - 0s 3ms/step - loss: 0.0865 - mse: 0.0865 - val_loss: 0.0681 - val_mse: 0.0681
# Epoch 71/200
# 80/80 [==============================] - 0s 3ms/step - loss: 0.0836 - mse: 0.0836 - val_loss: 0.0873 - val_mse: 0.0873
# Epoch 72/200
# 80/80 [==============================] - 0s 4ms/step - loss: 0.1076 - mse: 0.1076 - val_loss: 0.0529 - val_mse: 0.0529
# Epoch 73/200
# 80/80 [==============================] - 0s 4ms/step - loss: 0.0724 - mse: 0.0724 - val_loss: 0.0905 - val_mse: 0.0905
# Epoch 74/200
# 80/80 [==============================] - 0s 4ms/step - loss: 0.1038 - mse: 0.1038 - val_loss: 0.0706 - val_mse: 0.0706
# Epoch 75/200
# 80/80 [==============================] - 0s 4ms/step - loss: 0.0803 - mse: 0.0803 - val_loss: 0.5759 - val_mse: 0.5759
# Epoch 76/200
# 80/80 [==============================] - 0s 3ms/step - loss: 0.1086 - mse: 0.1086 - val_loss: 0.0637 - val_mse: 0.0637
# Epoch 77/200
# 80/80 [==============================] - 0s 4ms/step - loss: 0.0975 - mse: 0.0975 - val_loss: 0.1200 - val_mse: 0.1200
# Epoch 78/200
# 80/80 [==============================] - 0s 4ms/step - loss: 0.0795 - mse: 0.0795 - val_loss: 0.0814 - val_mse: 0.0814
# Epoch 79/200
# 80/80 [==============================] - 0s 5ms/step - loss: 0.0970 - mse: 0.0970 - val_loss: 0.0640 - val_mse: 0.0640
# Epoch 80/200
# 80/80 [==============================] - 0s 4ms/step - loss: 0.0936 - mse: 0.0936 - val_loss: 0.0853 - val_mse: 0.0853
# Epoch 81/200
# 80/80 [==============================] - 0s 4ms/step - loss: 0.0851 - mse: 0.0851 - val_loss: 0.0897 - val_mse: 0.0897
# Epoch 82/200
# 80/80 [==============================] - 0s 4ms/step - loss: 0.0877 - mse: 0.0877 - val_loss: 0.0584 - val_mse: 0.0584
# Epoch 83/200
# 80/80 [==============================] - 0s 4ms/step - loss: 0.0717 - mse: 0.0717 - val_loss: 0.4640 - val_mse: 0.4640
# Epoch 84/200
# 80/80 [==============================] - 0s 4ms/step - loss: 0.0937 - mse: 0.0937 - val_loss: 0.0618 - val_mse: 0.0618
# Epoch 85/200
# 80/80 [==============================] - 0s 4ms/step - loss: 0.1457 - mse: 0.1457 - val_loss: 0.0676 - val_mse: 0.0676
# Epoch 86/200
# 80/80 [==============================] - 0s 4ms/step - loss: 0.0705 - mse: 0.0705 - val_loss: 0.0582 - val_mse: 0.0582
# Epoch 87/200
# 80/80 [==============================] - 0s 4ms/step - loss: 0.0775 - mse: 0.0775 - val_loss: 0.0529 - val_mse: 0.0529
# Epoch 88/200
# 80/80 [==============================] - 0s 4ms/step - loss: 0.1021 - mse: 0.1021 - val_loss: 0.1313 - val_mse: 0.1313
# Epoch 89/200
# 80/80 [==============================] - 0s 4ms/step - loss: 0.0875 - mse: 0.0875 - val_loss: 0.0639 - val_mse: 0.0639
# Epoch 90/200
# 80/80 [==============================] - 0s 4ms/step - loss: 0.0870 - mse: 0.0870 - val_loss: 0.0552 - val_mse: 0.0552
# Epoch 91/200
# 80/80 [==============================] - 0s 4ms/step - loss: 0.0748 - mse: 0.0748 - val_loss: 0.0655 - val_mse: 0.0655
# Epoch 92/200
# 80/80 [==============================] - 0s 4ms/step - loss: 0.1257 - mse: 0.1257 - val_loss: 0.0653 - val_mse: 0.0653
# Epoch 93/200
# 80/80 [==============================] - 0s 3ms/step - loss: 0.0862 - mse: 0.0862 - val_loss: 0.0576 - val_mse: 0.0576
# Epoch 94/200
# 80/80 [==============================] - 0s 4ms/step - loss: 0.0898 - mse: 0.0898 - val_loss: 0.0562 - val_mse: 0.0562
# Epoch 95/200
# 80/80 [==============================] - 0s 3ms/step - loss: 0.0827 - mse: 0.0827 - val_loss: 0.0666 - val_mse: 0.0666
# Epoch 96/200
# 80/80 [==============================] - 0s 3ms/step - loss: 0.0808 - mse: 0.0808 - val_loss: 0.0675 - val_mse: 0.0675
# Epoch 97/200
# 80/80 [==============================] - 0s 4ms/step - loss: 0.0747 - mse: 0.0747 - val_loss: 0.0570 - val_mse: 0.0570
# Epoch 98/200
# 80/80 [==============================] - 0s 4ms/step - loss: 0.0757 - mse: 0.0757 - val_loss: 0.0805 - val_mse: 0.0805
# Epoch 99/200
# 80/80 [==============================] - 0s 4ms/step - loss: 0.0875 - mse: 0.0875 - val_loss: 0.0831 - val_mse: 0.0831
# Epoch 100/200
# 80/80 [==============================] - 0s 4ms/step - loss: 0.0875 - mse: 0.0875 - val_loss: 0.0520 - val_mse: 0.0520
# Epoch 101/200
# 80/80 [==============================] - 0s 4ms/step - loss: 0.0756 - mse: 0.0756 - val_loss: 0.0718 - val_mse: 0.0718
# Epoch 102/200
# 80/80 [==============================] - 0s 3ms/step - loss: 0.0787 - mse: 0.0787 - val_loss: 0.1184 - val_mse: 0.1184
# Epoch 103/200
# 80/80 [==============================] - 0s 4ms/step - loss: 0.0860 - mse: 0.0860 - val_loss: 0.0512 - val_mse: 0.0512
# Epoch 104/200
# 80/80 [==============================] - 0s 4ms/step - loss: 0.1283 - mse: 0.1283 - val_loss: 0.0545 - val_mse: 0.0545
# Epoch 105/200
# 80/80 [==============================] - 0s 3ms/step - loss: 0.0821 - mse: 0.0821 - val_loss: 0.0818 - val_mse: 0.0818
# Epoch 106/200
# 80/80 [==============================] - 0s 4ms/step - loss: 0.1246 - mse: 0.1246 - val_loss: 0.0709 - val_mse: 0.0709
# Epoch 107/200
# 80/80 [==============================] - 0s 4ms/step - loss: 0.1017 - mse: 0.1017 - val_loss: 0.0890 - val_mse: 0.0890
# Epoch 108/200
# 80/80 [==============================] - 0s 4ms/step - loss: 0.1129 - mse: 0.1129 - val_loss: 0.0727 - val_mse: 0.0727
# Epoch 109/200
# 80/80 [==============================] - 0s 4ms/step - loss: 0.0762 - mse: 0.0762 - val_loss: 0.0875 - val_mse: 0.0875
# Epoch 110/200
# 80/80 [==============================] - 0s 4ms/step - loss: 0.0870 - mse: 0.0870 - val_loss: 0.0527 - val_mse: 0.0527
# Epoch 111/200
# 80/80 [==============================] - 0s 4ms/step - loss: 0.0908 - mse: 0.0908 - val_loss: 0.0528 - val_mse: 0.0528
# Epoch 112/200
# 80/80 [==============================] - 0s 4ms/step - loss: 0.0817 - mse: 0.0817 - val_loss: 0.3017 - val_mse: 0.3017
# Epoch 113/200
# 80/80 [==============================] - 0s 3ms/step - loss: 0.0890 - mse: 0.0890 - val_loss: 0.0606 - val_mse: 0.0606
# Epoch 114/200
# 80/80 [==============================] - 0s 4ms/step - loss: 0.1154 - mse: 0.1154 - val_loss: 0.1932 - val_mse: 0.1932
# Epoch 115/200
# 80/80 [==============================] - 0s 4ms/step - loss: 0.0971 - mse: 0.0971 - val_loss: 0.1260 - val_mse: 0.1260
# Epoch 116/200
# 80/80 [==============================] - 0s 4ms/step - loss: 0.1016 - mse: 0.1016 - val_loss: 0.0720 - val_mse: 0.0720
# Epoch 117/200
# 80/80 [==============================] - 0s 4ms/step - loss: 0.0734 - mse: 0.0734 - val_loss: 0.0586 - val_mse: 0.0586
# Epoch 118/200
# 80/80 [==============================] - 0s 4ms/step - loss: 0.0716 - mse: 0.0716 - val_loss: 0.0545 - val_mse: 0.0545
# Epoch 119/200
# 80/80 [==============================] - 0s 4ms/step - loss: 0.0925 - mse: 0.0925 - val_loss: 0.1742 - val_mse: 0.1742
# Epoch 120/200
# 80/80 [==============================] - 0s 4ms/step - loss: 0.1073 - mse: 0.1073 - val_loss: 0.0685 - val_mse: 0.0685
# Epoch 121/200
# 80/80 [==============================] - 0s 4ms/step - loss: 0.0837 - mse: 0.0837 - val_loss: 0.0962 - val_mse: 0.0962
# Epoch 122/200
# 80/80 [==============================] - 0s 4ms/step - loss: 0.1048 - mse: 0.1048 - val_loss: 0.0531 - val_mse: 0.0531
# Epoch 123/200
# 80/80 [==============================] - 0s 3ms/step - loss: 0.0746 - mse: 0.0746 - val_loss: 0.1127 - val_mse: 0.1127
# Epoch 124/200
# 80/80 [==============================] - 0s 4ms/step - loss: 0.1050 - mse: 0.1050 - val_loss: 0.0734 - val_mse: 0.0734
# Epoch 125/200
# 80/80 [==============================] - 0s 4ms/step - loss: 0.0740 - mse: 0.0740 - val_loss: 0.0615 - val_mse: 0.0615
# Epoch 126/200
# 80/80 [==============================] - 0s 4ms/step - loss: 0.0901 - mse: 0.0901 - val_loss: 0.0714 - val_mse: 0.0714
# Epoch 127/200
# 80/80 [==============================] - 0s 3ms/step - loss: 0.0970 - mse: 0.0970 - val_loss: 0.0775 - val_mse: 0.0775
# Epoch 128/200
# 80/80 [==============================] - 0s 4ms/step - loss: 0.0837 - mse: 0.0837 - val_loss: 0.0542 - val_mse: 0.0542
# Epoch 129/200
# 80/80 [==============================] - 0s 4ms/step - loss: 0.1203 - mse: 0.1203 - val_loss: 0.1576 - val_mse: 0.1576
# Epoch 130/200
# 80/80 [==============================] - 0s 4ms/step - loss: 0.0767 - mse: 0.0767 - val_loss: 0.1022 - val_mse: 0.1022
# Epoch 131/200
# 80/80 [==============================] - 0s 3ms/step - loss: 0.1083 - mse: 0.1083 - val_loss: 0.0601 - val_mse: 0.0601
# Epoch 132/200
# 80/80 [==============================] - 0s 4ms/step - loss: 0.0725 - mse: 0.0725 - val_loss: 0.0640 - val_mse: 0.0640
# Epoch 133/200
# 80/80 [==============================] - 0s 4ms/step - loss: 0.0890 - mse: 0.0890 - val_loss: 0.1262 - val_mse: 0.1262
# Epoch 134/200
# 80/80 [==============================] - 0s 4ms/step - loss: 0.0726 - mse: 0.0726 - val_loss: 0.1119 - val_mse: 0.1119
# Epoch 135/200
# 80/80 [==============================] - 0s 4ms/step - loss: 0.0910 - mse: 0.0910 - val_loss: 0.0699 - val_mse: 0.0699
# Epoch 136/200
# 80/80 [==============================] - 0s 4ms/step - loss: 0.0911 - mse: 0.0911 - val_loss: 0.0920 - val_mse: 0.0920
# Epoch 137/200
# 80/80 [==============================] - 0s 4ms/step - loss: 0.1005 - mse: 0.1005 - val_loss: 0.0624 - val_mse: 0.0624
# Epoch 138/200
# 80/80 [==============================] - 0s 4ms/step - loss: 0.0944 - mse: 0.0944 - val_loss: 0.0754 - val_mse: 0.0754
# Epoch 139/200
# 80/80 [==============================] - 0s 4ms/step - loss: 0.0891 - mse: 0.0891 - val_loss: 0.0524 - val_mse: 0.0524
# Epoch 140/200
# 80/80 [==============================] - 0s 4ms/step - loss: 0.0872 - mse: 0.0872 - val_loss: 0.1001 - val_mse: 0.1001
# Epoch 141/200
# 80/80 [==============================] - 0s 4ms/step - loss: 0.1106 - mse: 0.1106 - val_loss: 0.1000 - val_mse: 0.1000
# Epoch 142/200
# 80/80 [==============================] - 0s 4ms/step - loss: 0.1188 - mse: 0.1188 - val_loss: 0.0576 - val_mse: 0.0576
# Epoch 143/200
# 80/80 [==============================] - 0s 4ms/step - loss: 0.0788 - mse: 0.0788 - val_loss: 0.1412 - val_mse: 0.1412
# Epoch 144/200
# 80/80 [==============================] - 0s 4ms/step - loss: 0.0802 - mse: 0.0802 - val_loss: 0.1066 - val_mse: 0.1066
# Epoch 145/200
# 80/80 [==============================] - 0s 4ms/step - loss: 0.1036 - mse: 0.1036 - val_loss: 0.0722 - val_mse: 0.0722
# Epoch 146/200
# 80/80 [==============================] - 0s 3ms/step - loss: 0.0901 - mse: 0.0901 - val_loss: 0.1125 - val_mse: 0.1125
# Epoch 147/200
# 80/80 [==============================] - 0s 4ms/step - loss: 0.0844 - mse: 0.0844 - val_loss: 0.2040 - val_mse: 0.2040
# Epoch 148/200
# 80/80 [==============================] - 0s 4ms/step - loss: 0.1018 - mse: 0.1018 - val_loss: 0.0551 - val_mse: 0.0551
# Epoch 149/200
# 80/80 [==============================] - 0s 4ms/step - loss: 0.0880 - mse: 0.0880 - val_loss: 0.0579 - val_mse: 0.0579
# Epoch 150/200
# 80/80 [==============================] - 0s 4ms/step - loss: 0.0941 - mse: 0.0941 - val_loss: 0.0599 - val_mse: 0.0599
# Epoch 151/200
# 80/80 [==============================] - 0s 5ms/step - loss: 0.0903 - mse: 0.0903 - val_loss: 0.1086 - val_mse: 0.1086
# Epoch 152/200
# 80/80 [==============================] - 0s 4ms/step - loss: 0.0734 - mse: 0.0734 - val_loss: 0.0759 - val_mse: 0.0759
# Epoch 153/200
# 80/80 [==============================] - 0s 4ms/step - loss: 0.1052 - mse: 0.1052 - val_loss: 0.0615 - val_mse: 0.0615
# Epoch 154/200
# 80/80 [==============================] - 0s 4ms/step - loss: 0.0820 - mse: 0.0820 - val_loss: 0.0636 - val_mse: 0.0636
# Epoch 155/200
# 80/80 [==============================] - 0s 4ms/step - loss: 0.0832 - mse: 0.0832 - val_loss: 0.0586 - val_mse: 0.0586
# Epoch 156/200
# 80/80 [==============================] - 0s 4ms/step - loss: 0.0771 - mse: 0.0771 - val_loss: 0.0619 - val_mse: 0.0619
# Epoch 157/200
# 80/80 [==============================] - 0s 4ms/step - loss: 0.1088 - mse: 0.1088 - val_loss: 0.0604 - val_mse: 0.0604
# Epoch 158/200
# 80/80 [==============================] - 0s 3ms/step - loss: 0.0695 - mse: 0.0695 - val_loss: 0.0525 - val_mse: 0.0525
# Epoch 159/200
# 80/80 [==============================] - 0s 4ms/step - loss: 0.1064 - mse: 0.1064 - val_loss: 0.0706 - val_mse: 0.0706
# Epoch 160/200
# 80/80 [==============================] - 0s 4ms/step - loss: 0.0816 - mse: 0.0816 - val_loss: 0.0593 - val_mse: 0.0593
# Epoch 161/200
# 80/80 [==============================] - 0s 4ms/step - loss: 0.0818 - mse: 0.0818 - val_loss: 0.2795 - val_mse: 0.2795
# Epoch 162/200
# 80/80 [==============================] - 0s 4ms/step - loss: 0.1440 - mse: 0.1440 - val_loss: 0.3463 - val_mse: 0.3463
# Epoch 163/200
# 80/80 [==============================] - 0s 4ms/step - loss: 0.1149 - mse: 0.1149 - val_loss: 0.0652 - val_mse: 0.0652
# Epoch 164/200
# 80/80 [==============================] - 0s 4ms/step - loss: 0.0689 - mse: 0.0689 - val_loss: 0.0603 - val_mse: 0.0603
# Epoch 165/200
# 80/80 [==============================] - 0s 4ms/step - loss: 0.0779 - mse: 0.0779 - val_loss: 0.1150 - val_mse: 0.1150
# Epoch 166/200
# 80/80 [==============================] - 0s 4ms/step - loss: 0.0771 - mse: 0.0771 - val_loss: 0.0516 - val_mse: 0.0516
# Epoch 167/200
# 80/80 [==============================] - 0s 4ms/step - loss: 0.1191 - mse: 0.1191 - val_loss: 0.0792 - val_mse: 0.0792
# Epoch 168/200
# 80/80 [==============================] - 0s 4ms/step - loss: 0.0760 - mse: 0.0760 - val_loss: 0.0692 - val_mse: 0.0692
# Epoch 169/200
# 80/80 [==============================] - 0s 4ms/step - loss: 0.1016 - mse: 0.1016 - val_loss: 0.0609 - val_mse: 0.0609
# Epoch 170/200
# 80/80 [==============================] - 0s 4ms/step - loss: 0.0810 - mse: 0.0810 - val_loss: 0.0549 - val_mse: 0.0549
# Epoch 171/200
# 80/80 [==============================] - 0s 4ms/step - loss: 0.0936 - mse: 0.0936 - val_loss: 0.0609 - val_mse: 0.0609
# Epoch 172/200
# 80/80 [==============================] - 0s 4ms/step - loss: 0.0875 - mse: 0.0875 - val_loss: 0.1175 - val_mse: 0.1175
# Epoch 173/200
# 80/80 [==============================] - 0s 3ms/step - loss: 0.0859 - mse: 0.0859 - val_loss: 0.0826 - val_mse: 0.0826
# Epoch 174/200
# 80/80 [==============================] - 0s 4ms/step - loss: 0.0709 - mse: 0.0709 - val_loss: 0.0549 - val_mse: 0.0549
# Epoch 175/200
# 80/80 [==============================] - 0s 4ms/step - loss: 0.1030 - mse: 0.1030 - val_loss: 0.1431 - val_mse: 0.1431
# Epoch 176/200
# 80/80 [==============================] - 0s 4ms/step - loss: 0.0829 - mse: 0.0829 - val_loss: 0.0524 - val_mse: 0.0524
# Epoch 177/200
# 80/80 [==============================] - 0s 4ms/step - loss: 0.0841 - mse: 0.0841 - val_loss: 0.1029 - val_mse: 0.1029
# Epoch 178/200
# 80/80 [==============================] - 0s 4ms/step - loss: 0.0950 - mse: 0.0950 - val_loss: 0.2073 - val_mse: 0.2073
# Epoch 179/200
# 80/80 [==============================] - 0s 3ms/step - loss: 0.1146 - mse: 0.1146 - val_loss: 0.0659 - val_mse: 0.0659
# Epoch 180/200
# 80/80 [==============================] - 0s 4ms/step - loss: 0.0842 - mse: 0.0842 - val_loss: 0.2185 - val_mse: 0.2185
# Epoch 181/200
# 80/80 [==============================] - 0s 3ms/step - loss: 0.1117 - mse: 0.1117 - val_loss: 0.0534 - val_mse: 0.0534
# Epoch 182/200
# 80/80 [==============================] - 0s 4ms/step - loss: 0.1134 - mse: 0.1134 - val_loss: 0.0567 - val_mse: 0.0567
# Epoch 183/200
# 80/80 [==============================] - 0s 4ms/step - loss: 0.1377 - mse: 0.1377 - val_loss: 0.0880 - val_mse: 0.0880
# Epoch 184/200
# 80/80 [==============================] - 0s 4ms/step - loss: 0.1173 - mse: 0.1173 - val_loss: 0.0621 - val_mse: 0.0621
# Epoch 185/200
# 80/80 [==============================] - 0s 4ms/step - loss: 0.0709 - mse: 0.0709 - val_loss: 0.0778 - val_mse: 0.0778
# Epoch 186/200
# 80/80 [==============================] - 0s 4ms/step - loss: 0.0771 - mse: 0.0771 - val_loss: 0.0740 - val_mse: 0.0740
# Epoch 187/200
# 80/80 [==============================] - 0s 4ms/step - loss: 0.0835 - mse: 0.0835 - val_loss: 0.0581 - val_mse: 0.0581
# Epoch 188/200
# 80/80 [==============================] - 0s 4ms/step - loss: 0.0951 - mse: 0.0951 - val_loss: 0.0689 - val_mse: 0.0689
# Epoch 189/200
# 80/80 [==============================] - 0s 4ms/step - loss: 0.0733 - mse: 0.0733 - val_loss: 0.0579 - val_mse: 0.0579
# Epoch 190/200
# 80/80 [==============================] - 0s 4ms/step - loss: 0.0869 - mse: 0.0869 - val_loss: 0.1952 - val_mse: 0.1952
# Epoch 191/200
# 80/80 [==============================] - 0s 4ms/step - loss: 0.0947 - mse: 0.0947 - val_loss: 0.0751 - val_mse: 0.0751
# Epoch 192/200
# 80/80 [==============================] - 0s 4ms/step - loss: 0.0821 - mse: 0.0821 - val_loss: 0.2109 - val_mse: 0.2109
# Epoch 193/200
# 80/80 [==============================] - 0s 4ms/step - loss: 0.0937 - mse: 0.0937 - val_loss: 0.0896 - val_mse: 0.0896
# Epoch 194/200
# 80/80 [==============================] - 0s 4ms/step - loss: 0.0856 - mse: 0.0856 - val_loss: 0.0567 - val_mse: 0.0567
# Epoch 195/200
# 80/80 [==============================] - 0s 4ms/step - loss: 0.0763 - mse: 0.0763 - val_loss: 0.0677 - val_mse: 0.0677
# Epoch 196/200
# 80/80 [==============================] - 0s 4ms/step - loss: 0.1060 - mse: 0.1060 - val_loss: 0.0612 - val_mse: 0.0612
# Epoch 197/200
# 80/80 [==============================] - 0s 4ms/step - loss: 0.0910 - mse: 0.0910 - val_loss: 0.0533 - val_mse: 0.0533
# Epoch 198/200
# 80/80 [==============================] - 0s 3ms/step - loss: 0.0776 - mse: 0.0776 - val_loss: 0.1920 - val_mse: 0.1920
# Epoch 199/200
# 80/80 [==============================] - 0s 3ms/step - loss: 0.0787 - mse: 0.0787 - val_loss: 0.0547 - val_mse: 0.0547
# Epoch 200/200
# 80/80 [==============================] - 0s 4ms/step - loss: 0.1109 - mse: 0.1109 - val_loss: 0.0673 - val_mse: 0.0673

# %%
#Graficar el MSE
fig, ax = plt.subplots(1, 1, figsize=(10,6))
ax.plot(np.sqrt(history.history['mse']), 'r', label='train')
ax.plot(np.sqrt(history.history['val_mse']), 'b' ,label='val')
ax.set_xlabel(r'Epoch', fontsize=20)
ax.set_ylabel(r'MSE', fontsize=20)
ax.legend()
ax.tick_params(labelsize=20)

# %%
#Evaluación del modelo

#Evaluación del modelo en los datos de prueba
score = model.evaluate(X_test,y_test)
print('Test mse:', score[1])
# Out:
# 63/63 [==============================] - 0s 2ms/step - loss: 0.0673 - mse: 0.0673
# Test mse: 0.06725972145795822

# %%
#Predicción  y calcular R2

#Con datos del test
yhat = model.predict(X_test)
R2_score = r2_score(y_test,yhat)
xmin,xmax = min(y_test),max(y_test)
xline = np.linspace(xmin,xmax)
fig = plt.figure(figsize=(10,6))
plt.scatter(y_test,yhat,label='Estimation')
plt.plot(xline,xline,'k--',label='Perfect estimation')
plt.xlabel('Real output', fontsize=20)
plt.ylabel('Estimation output', fontsize=20)
plt.title('Test R^2=%0.4f'%R2_score, fontsize=20)
plt.legend()
plt.grid()
plt.show()
# Out:
# 63/63 [==============================] - 0s 2ms/step

# %%
print('R2:', R2_score)
# Out:
# R2: 0.9320278801887141

# %% [markdown]
# #### Ejemplo Cross Validation

# %%
### Cross Validation
from scikeras.wrappers import KerasClassifier, KerasRegressor
from sklearn.model_selection import cross_val_score

# %%
# Crear función que regresa una red neuronal compilada
def create_network():
    
    # Iniciar objeto de red neuronal
    network = Sequential()

    # Añadir una capa de entrada
    network.add(Dense(5, activation='tanh', input_dim=2,name='input_layer')) #Relu

    # Añadir capa oculta
    #network.add(Dense(10, activation='relu')) #tanh

    # Añadir capa de salida
    network.add(Dense(1, activation='linear'))
    
    opt = keras.optimizers.SGD(learning_rate=learning_rate,momentum=momentum,
                           decay=decay_rate)
    
    # Compilar la red neuronal
    network.compile(loss='mean_squared_error', 
                    optimizer=opt, 
                    metrics=['mse']) 
    
    #regresa la red compilada
    return network

# %%
# Hacer el modelo en keras para que pueda ser usado por scikit-learn
neural_network = KerasRegressor(build_fn=create_network, 
                                 epochs=200, 
                                 batch_size=100, 
                                 verbose=0)

# %%
# Evaluar la red neuronal usando 4-fold cross-validation
print('MSE:', (-cross_val_score(neural_network, X, Y, cv=4,  scoring='neg_mean_squared_error')).mean())
# Out:
# MSE: nan
# C:\Users\Juan Pablo Colome\anaconda3\lib\site-packages\scikeras\wrappers.py:915: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# C:\Users\Juan Pablo Colome\anaconda3\lib\site-packages\scikeras\wrappers.py:915: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# C:\Users\Juan Pablo Colome\anaconda3\lib\site-packages\scikeras\wrappers.py:915: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# C:\Users\Juan Pablo Colome\anaconda3\lib\site-packages\scikeras\wrappers.py:915: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# C:\Users\Juan Pablo Colome\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 4 fits failed out of a total of 4.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 4 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\Juan Pablo Colome\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Juan Pablo Colome\anaconda3\lib\site-packages\scikeras\wrappers.py", line 760, in fit
#     self._fit(
#   File "C:\Users\Juan Pablo Colome\anaconda3\lib\site-packages\scikeras\wrappers.py", line 915, in _fit
#     X, y = self._initialize(X, y)
#   File "C:\Users\Juan Pablo Colome\anaconda3\lib\site-packages\scikeras\wrappers.py", line 852, in _initialize
#     self.model_ = self._build_keras_model()
#   File "C:\Users\Juan Pablo Colome\anaconda3\lib\site-packages\scikeras\wrappers.py", line 429, in _build_keras_model
#     model = final_build_fn(**build_params)
#   File "C:\Users\Juan Pablo Colome\AppData\Local\Temp\ipykernel_11476\2536443211.py", line 16, in create_network
#     opt = keras.optimizers.SGD(learning_rate=learning_rate,momentum=momentum,
#   File "C:\Users\Juan Pablo Colome\anaconda3\lib\site-packages\keras\src\optimizers\sgd.py", line 114, in __init__
#     super().__init__(
#   File "C:\Users\Juan Pablo Colome\anaconda3\lib\site-packages\keras\src\optimizers\optimizer.py", line 1094, in __init__
#     super().__init__(
#   File "C:\Users\Juan Pablo Colome\anaconda3\lib\site-packages\keras\src\optimizers\optimizer.py", line 106, in __init__
#     self._process_kwargs(kwargs)
#   File "C:\Users\Juan Pablo Colome\anaconda3\lib\site-packages\keras\src\optimizers\optimizer.py", line 135, in _process_kwargs
#     raise ValueError(
# ValueError: decay is deprecated in the new Keras optimizer, please check the docstring for valid arguments, or use the legacy optimizer, e.g., tf.keras.optimizers.legacy.SGD.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)

# %%
print('R2:', (cross_val_score(neural_network, X, Y, cv=4,  scoring='r2')).mean())
# Out:
# C:\Users\Juan Pablo Colome\anaconda3\lib\site-packages\scikeras\wrappers.py:915: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# C:\Users\Juan Pablo Colome\anaconda3\lib\site-packages\scikeras\wrappers.py:915: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# C:\Users\Juan Pablo Colome\anaconda3\lib\site-packages\scikeras\wrappers.py:915: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# R2: nan
# C:\Users\Juan Pablo Colome\anaconda3\lib\site-packages\scikeras\wrappers.py:915: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# C:\Users\Juan Pablo Colome\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 4 fits failed out of a total of 4.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 4 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\Juan Pablo Colome\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Juan Pablo Colome\anaconda3\lib\site-packages\scikeras\wrappers.py", line 760, in fit
#     self._fit(
#   File "C:\Users\Juan Pablo Colome\anaconda3\lib\site-packages\scikeras\wrappers.py", line 915, in _fit
#     X, y = self._initialize(X, y)
#   File "C:\Users\Juan Pablo Colome\anaconda3\lib\site-packages\scikeras\wrappers.py", line 852, in _initialize
#     self.model_ = self._build_keras_model()
#   File "C:\Users\Juan Pablo Colome\anaconda3\lib\site-packages\scikeras\wrappers.py", line 429, in _build_keras_model
#     model = final_build_fn(**build_params)
#   File "C:\Users\Juan Pablo Colome\AppData\Local\Temp\ipykernel_11476\2536443211.py", line 16, in create_network
#     opt = keras.optimizers.SGD(learning_rate=learning_rate,momentum=momentum,
#   File "C:\Users\Juan Pablo Colome\anaconda3\lib\site-packages\keras\src\optimizers\sgd.py", line 114, in __init__
#     super().__init__(
#   File "C:\Users\Juan Pablo Colome\anaconda3\lib\site-packages\keras\src\optimizers\optimizer.py", line 1094, in __init__
#     super().__init__(
#   File "C:\Users\Juan Pablo Colome\anaconda3\lib\site-packages\keras\src\optimizers\optimizer.py", line 106, in __init__
#     self._process_kwargs(kwargs)
#   File "C:\Users\Juan Pablo Colome\anaconda3\lib\site-packages\keras\src\optimizers\optimizer.py", line 135, in _process_kwargs
#     raise ValueError(
# ValueError: decay is deprecated in the new Keras optimizer, please check the docstring for valid arguments, or use the legacy optimizer, e.g., tf.keras.optimizers.legacy.SGD.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)

# %% [markdown]
# ### Optimización de hiperparámetros
#
# **GridSearch**
#
# ![GridSearch](https://www.yourdatateacher.com/wp-content/uploads/2021/03/image-7.png)

# %% [markdown]
# ### Ventajas y desventajas de las redes neuronales
#
# #### Ventajas
#
# - Capacidad de trabajar con información incompleta
# - Si algo llega a fallar en una neurona, se pueden aún obtener resultados - Tolerantes a fallas
# - Tienen la capacidad de aprender por sí mismas y generar resultados que no se limitan a la información que se les dió al principio.
# - Capacidad de procesamiento en paralelo
# - Autoorganización: la capacidad de agrupar y clasificar grandes cantidades de datos hace que las redes neuronales sean especialmente adecuadas para organizar los complicados problemas visuales que plantea el análisis de imágenes
#
# #### Desventajas
#
# - Debido a su naturaleza de "caja negra" se pierde interpretación del modelo
# - Usualmente requieren muchos más datos que los modelos tradicionales
# - Si hay demasiados datos, la red neuronal requiere procesadores con gran poder de procesamiento
# - No hay regla específica para determinar la estructura de la red - Prueba y error
# - Pueden llegar a convertirse muy complejas

# %% [markdown]
# #### Algunas referencias
#
# - https://keras.io/guides/sequential_model/
# - https://keras.io/api/layers/activations/
# - https://keras.io/optimizers/
# - https://playground.tensorflow.org/#activation=tanh&batchSize=10&dataset=spiral&regDataset=reg-gauss&learningRate=0.03&regularizationRate=0.003&noise=20&networkShape=4&seed=0.82538&showTestData=false&discretize=false&percTrainData=50&x=true&y=true&xTimesY=false&xSquared=false&ySquared=false&cosX=false&sinX=false&cosY=false&sinY=false&collectStats=false&problem=regression&initZero=false&hideText=false
